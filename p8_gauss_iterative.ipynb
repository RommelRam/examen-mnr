# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Ejercicio 1

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A = [[2,1],[3,2]]
b = [5,8]
# Out:
# [02-12 15:04:32][INFO][P3E009-E] 2026-02-12 15:04:32.509260
# [02-12 15:04:32][INFO][P3E009-E] 2026-02-12 15:04:32.547589
# [02-12 15:04:32][INFO][P3E009-E] 2026-02-12 15:04:32.548644

# %% [markdown]
# # Ejercicio 2

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A = [[2,1],[3,2]]
b = [5,8]

# %% [markdown]
# # Código para dibujar

# %%
import numpy as np

A = [[2,1],[3,2]]
b = [5,8]
iteraciones=10
xi = [0,0]

x_values = []
y_values = []
for i in range(iteraciones):
    xi = gauss_jacobi(A=A, b=b, x=xi, tol=1e-5, max_iter=1)
    x_values.append(xi[0])
    y_values.append(xi[1])  

y_values = np.array(y_values).reshape(-1, 1)
x_values = np.array(x_values)

"""Resuelve el sistema de ecuaciones lineales Ax = b mediante el método de Gauss-Seidel.

    ## Parameters
    ``A``: Matriz de coeficientes del sistema de ecuaciones lineales.
    ``b``: Vector de términos independientes del sistema de ecuaciones lineales.
    ``x0``: Vector de aproximación inicial.
    ``tol``: Tolerancia.
    ``max_iter``: Número máximo de iteraciones.

    ## Return
    ``x``: Vector solución del sistema de ecuaciones lineales.
    """


import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D

plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# [02-12 15:44:44][INFO][P3E009-E] i= 0 x: [[0. 0.]]
# [02-12 15:44:44][INFO][P3E009-E] i= 1 x: [[2.5 4. ]]
# [02-12 15:44:44][INFO][P3E009-E] i= 0 x: [[2.5 4. ]]
# [02-12 15:44:44][INFO][P3E009-E] i= 1 x: [[0.5  0.25]]
# [02-12 15:44:44][INFO][P3E009-E] i= 0 x: [[0.5  0.25]]
# [02-12 15:44:44][INFO][P3E009-E] i= 1 x: [[2.375 3.25 ]]
# [02-12 15:44:44][INFO][P3E009-E] i= 0 x: [[2.375 3.25 ]]
# [02-12 15:44:44][INFO][P3E009-E] i= 1 x: [[0.875  0.4375]]
# [02-12 15:44:44][INFO][P3E009-E] i= 0 x: [[0.875  0.4375]]
# [02-12 15:44:44][INFO][P3E009-E] i= 1 x: [[2.28125 2.6875 ]]
# [02-12 15:44:44][INFO][P3E009-E] i= 0 x: [[2.28125 2.6875 ]]
# [02-12 15:44:44][INFO][P3E009-E] i= 1 x: [[1.15625  0.578125]]
# [02-12 15:44:44][INFO][P3E009-E] i= 0 x: [[1.15625  0.578125]]
# [02-12 15:44:44][INFO][P3E009-E] i= 1 x: [[2.2109375 2.265625 ]]
# [02-12 15:44:44][INFO][P3E009-E] i= 0 x: [[2.2109375 2.265625 ]]
# [02-12 15:44:44][INFO][P3E009-E] i= 1 x: [[1.3671875  0.68359375]]
# [02-12 15:44:44][INFO][P3E009-E] i= 0 x: [[1.3671875  0.68359375]]
# [02-12 15:44:44][INFO][P3E009-E] i= 1 x: [[2.15820312 1.94921875]]
# [02-12 15:44:44][INFO][P3E009-E] i= 0 x: [[2.15820312 1.94921875]]
# [02-12 15:44:44][INFO][P3E009-E] i= 1 x: [[1.52539062 0.76269531]]

# %%
import numpy as np

A = [[2,1],[3,2]]
b = [5,8]
iteraciones=10
xi = [0,0]
gauss_seidel(A=A, b=b, x=xi, tol=1e-5, max_iter=iteraciones)
x_values = []
y_values = []
for i in range(iteraciones):
    xi = gauss_seidel(A=A, b=b, x=xi, tol=1e-5, max_iter=1)
    x_values.append(xi[0])
    y_values.append(xi[1])  

y_values = np.array(y_values).reshape(-1, 1)
x_values = np.array(x_values)

"""Resuelve el sistema de ecuaciones lineales Ax = b mediante el método de Gauss-Seidel.

    ## Parameters
    ``A``: Matriz de coeficientes del sistema de ecuaciones lineales.
    ``b``: Vector de términos independientes del sistema de ecuaciones lineales.
    ``x0``: Vector de aproximación inicial.
    ``tol``: Tolerancia.
    ``max_iter``: Número máximo de iteraciones.

    ## Return
    ``x``: Vector solución del sistema de ecuaciones lineales.
    """


import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D

plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# [02-12 15:45:30][INFO][P3E009-E] i= 0 x: [[0. 0.]]
# [02-12 15:45:30][INFO][P3E009-E] i= 1 x: [[2.5  0.25]]
# [02-12 15:45:30][INFO][P3E009-E] i= 2 x: [[2.375  0.4375]]
# [02-12 15:45:30][INFO][P3E009-E] i= 3 x: [[2.28125  0.578125]]
# [02-12 15:45:30][INFO][P3E009-E] i= 4 x: [[2.2109375  0.68359375]]
# [02-12 15:45:30][INFO][P3E009-E] i= 5 x: [[2.15820312 0.76269531]]
# [02-12 15:45:30][INFO][P3E009-E] i= 6 x: [[2.11865234 0.82202148]]
# [02-12 15:45:30][INFO][P3E009-E] i= 7 x: [[2.08898926 0.86651611]]
# [02-12 15:45:30][INFO][P3E009-E] i= 8 x: [[2.06674194 0.89988708]]
# [02-12 15:45:30][INFO][P3E009-E] i= 9 x: [[2.05005646 0.92491531]]
# [02-12 15:45:30][INFO][P3E009-E] i= 10 x: [[2.03754234 0.94368649]]
# [02-12 15:45:30][INFO][P3E009-E] i= 0 x: [[0. 0.]]
# [02-12 15:45:30][INFO][P3E009-E] i= 1 x: [[2.5  0.25]]
# [02-12 15:45:30][INFO][P3E009-E] i= 0 x: [[2.5  0.25]]
# [02-12 15:45:30][INFO][P3E009-E] i= 1 x: [[2.375  0.4375]]
# [02-12 15:45:30][INFO][P3E009-E] i= 0 x: [[2.375  0.4375]]
# [02-12 15:45:30][INFO][P3E009-E] i= 1 x: [[2.28125  0.578125]]
# [02-12 15:45:30][INFO][P3E009-E] i= 0 x: [[2.28125  0.578125]]
# [02-12 15:45:30][INFO][P3E009-E] i= 1 x: [[2.2109375  0.68359375]]
# [02-12 15:45:30][INFO][P3E009-E] i= 0 x: [[2.2109375  0.68359375]]
# [02-12 15:45:30][INFO][P3E009-E] i= 1 x: [[2.15820312 0.76269531]]
# [02-12 15:45:30][INFO][P3E009-E] i= 0 x: [[2.15820312 0.76269531]]
# [02-12 15:45:30][INFO][P3E009-E] i= 1 x: [[2.11865234 0.82202148]]
# [02-12 15:45:30][INFO][P3E009-E] i= 0 x: [[2.11865234 0.82202148]]
# [02-12 15:45:30][INFO][P3E009-E] i= 1 x: [[2.08898926 0.86651611]]
# [02-12 15:45:30][INFO][P3E009-E] i= 0 x: [[2.08898926 0.86651611]]
# [02-12 15:45:30][INFO][P3E009-E] i= 1 x: [[2.06674194 0.89988708]]
# [02-12 15:45:30][INFO][P3E009-E] i= 0 x: [[2.06674194 0.89988708]]
# [02-12 15:45:30][INFO][P3E009-E] i= 1 x: [[2.05005646 0.92491531]]
# [02-12 15:45:30][INFO][P3E009-E] i= 0 x: [[2.05005646 0.92491531]]
# [02-12 15:45:30][INFO][P3E009-E] i= 1 x: [[2.03754234 0.94368649]]

# %%
A = [[-2,1],[1,1]]
b = [0,6]

import numpy as np
iteraciones=10
xi = [0,0]
gauss_jacobi(A=A, b=b, x=xi, tol=1e-5, max_iter=iteraciones)
x_values = []
y_values = []
for i in range(iteraciones):
    xi = gauss_jacobi(A=A, b=b, x=xi, tol=1e-5, max_iter=1)
    x_values.append(xi[0])
    y_values.append(xi[1])  

y_values = np.array(y_values).reshape(-1, 1)
x_values = np.array(x_values)

"""Resuelve el sistema de ecuaciones lineales Ax = b mediante el método de Gauss-Seidel.

    ## Parameters
    ``A``: Matriz de coeficientes del sistema de ecuaciones lineales.
    ``b``: Vector de términos independientes del sistema de ecuaciones lineales.
    ``x0``: Vector de aproximación inicial.
    ``tol``: Tolerancia.
    ``max_iter``: Número máximo de iteraciones.

    ## Return
    ``x``: Vector solución del sistema de ecuaciones lineales.
    """


import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D

plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# [02-12 15:41:08][INFO][P3E009-E] i= 0 x: [[0. 0.]]
# [02-12 15:41:08][INFO][P3E009-E] i= 10 x: [[2.0625 4.125 ]]
# [02-12 15:41:08][INFO][P3E009-E] i= 0 x: [[0. 0.]]
# [02-12 15:41:08][INFO][P3E009-E] i= 1 x: [[-0.  6.]]
# [02-12 15:41:08][INFO][P3E009-E] i= 0 x: [[-0.  6.]]
# [02-12 15:41:08][INFO][P3E009-E] i= 1 x: [[3. 6.]]
# [02-12 15:41:08][INFO][P3E009-E] i= 0 x: [[3. 6.]]
# [02-12 15:41:08][INFO][P3E009-E] i= 1 x: [[3. 3.]]
# [02-12 15:41:08][INFO][P3E009-E] i= 0 x: [[3. 3.]]
# [02-12 15:41:08][INFO][P3E009-E] i= 1 x: [[1.5 3. ]]
# [02-12 15:41:08][INFO][P3E009-E] i= 0 x: [[1.5 3. ]]
# [02-12 15:41:08][INFO][P3E009-E] i= 1 x: [[1.5 4.5]]
# [02-12 15:41:08][INFO][P3E009-E] i= 0 x: [[1.5 4.5]]
# [02-12 15:41:08][INFO][P3E009-E] i= 1 x: [[2.25 4.5 ]]
# [02-12 15:41:08][INFO][P3E009-E] i= 0 x: [[2.25 4.5 ]]
# [02-12 15:41:08][INFO][P3E009-E] i= 1 x: [[2.25 3.75]]
# [02-12 15:41:08][INFO][P3E009-E] i= 0 x: [[2.25 3.75]]
# [02-12 15:41:08][INFO][P3E009-E] i= 1 x: [[1.875 3.75 ]]
# [02-12 15:41:08][INFO][P3E009-E] i= 0 x: [[1.875 3.75 ]]
# [02-12 15:41:08][INFO][P3E009-E] i= 1 x: [[1.875 4.125]]
# [02-12 15:41:08][INFO][P3E009-E] i= 0 x: [[1.875 4.125]]
# [02-12 15:41:08][INFO][P3E009-E] i= 1 x: [[2.0625 4.125 ]]

# %%
A = [[-2,1],[1,1]]
b = [0,6]

import numpy as np
iteraciones=10
xi = [0,0]
gauss_seidel(A=A, b=b, x=xi, tol=1e-5, max_iter=iteraciones)
x_values = []
y_values = []
for i in range(iteraciones):
    xi = gauss_seidel(A=A, b=b, x=xi, tol=1e-5, max_iter=1)
    x_values.append(xi[0])
    y_values.append(xi[1])  

y_values = np.array(y_values).reshape(-1, 1)
x_values = np.array(x_values)

"""Resuelve el sistema de ecuaciones lineales Ax = b mediante el método de Gauss-Seidel.

    ## Parameters
    ``A``: Matriz de coeficientes del sistema de ecuaciones lineales.
    ``b``: Vector de términos independientes del sistema de ecuaciones lineales.
    ``x0``: Vector de aproximación inicial.
    ``tol``: Tolerancia.
    ``max_iter``: Número máximo de iteraciones.

    ## Return
    ``x``: Vector solución del sistema de ecuaciones lineales.
    """


import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D

plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# [02-12 15:40:55][INFO][P3E009-E] i= 0 x: [[0. 0.]]
# [02-12 15:40:55][INFO][P3E009-E] i= 1 x: [[-0.  6.]]
# [02-12 15:40:55][INFO][P3E009-E] i= 2 x: [[3. 3.]]
# [02-12 15:40:55][INFO][P3E009-E] i= 3 x: [[1.5 4.5]]
# [02-12 15:40:55][INFO][P3E009-E] i= 4 x: [[2.25 3.75]]
# [02-12 15:40:55][INFO][P3E009-E] i= 5 x: [[1.875 4.125]]
# [02-12 15:40:55][INFO][P3E009-E] i= 6 x: [[2.0625 3.9375]]
# [02-12 15:40:55][INFO][P3E009-E] i= 7 x: [[1.96875 4.03125]]
# [02-12 15:40:55][INFO][P3E009-E] i= 8 x: [[2.015625 3.984375]]
# [02-12 15:40:55][INFO][P3E009-E] i= 9 x: [[1.9921875 4.0078125]]
# [02-12 15:40:55][INFO][P3E009-E] i= 10 x: [[2.00390625 3.99609375]]
# [02-12 15:40:55][INFO][P3E009-E] i= 0 x: [[0. 0.]]
# [02-12 15:40:55][INFO][P3E009-E] i= 1 x: [[-0.  6.]]
# [02-12 15:40:55][INFO][P3E009-E] i= 0 x: [[-0.  6.]]
# [02-12 15:40:55][INFO][P3E009-E] i= 1 x: [[3. 3.]]
# [02-12 15:40:55][INFO][P3E009-E] i= 0 x: [[3. 3.]]
# [02-12 15:40:55][INFO][P3E009-E] i= 1 x: [[1.5 4.5]]
# [02-12 15:40:55][INFO][P3E009-E] i= 0 x: [[1.5 4.5]]
# [02-12 15:40:55][INFO][P3E009-E] i= 1 x: [[2.25 3.75]]
# [02-12 15:40:55][INFO][P3E009-E] i= 0 x: [[2.25 3.75]]
# [02-12 15:40:55][INFO][P3E009-E] i= 1 x: [[1.875 4.125]]
# [02-12 15:40:55][INFO][P3E009-E] i= 0 x: [[1.875 4.125]]
# [02-12 15:40:55][INFO][P3E009-E] i= 1 x: [[2.0625 3.9375]]
# [02-12 15:40:55][INFO][P3E009-E] i= 0 x: [[2.0625 3.9375]]
# [02-12 15:40:55][INFO][P3E009-E] i= 1 x: [[1.96875 4.03125]]
# [02-12 15:40:55][INFO][P3E009-E] i= 0 x: [[1.96875 4.03125]]
# [02-12 15:40:55][INFO][P3E009-E] i= 1 x: [[2.015625 3.984375]]
# [02-12 15:40:55][INFO][P3E009-E] i= 0 x: [[2.015625 3.984375]]
# [02-12 15:40:55][INFO][P3E009-E] i= 1 x: [[1.9921875 4.0078125]]
# [02-12 15:40:55][INFO][P3E009-E] i= 0 x: [[1.9921875 4.0078125]]
# [02-12 15:40:55][INFO][P3E009-E] i= 1 x: [[2.00390625 3.99609375]]
